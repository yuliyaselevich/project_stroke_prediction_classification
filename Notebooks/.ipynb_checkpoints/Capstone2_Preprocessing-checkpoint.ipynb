# %% [markdown]
# # Preprocessing

# %%
# import required modules
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
# %matplotlib inline 
sns.set(style='ticks')

# %%
# Load the DataFrame
data_adult=pd.read_csv('C:/Users/Julia/Documents/_DATA SCIENCE/_Capstones/Capstone 2/Data/Data_adult.csv',index_col=0)

# %% [markdown]
# ## Age, bmi and avg_glucose_level are the only continuous variables in the dataset. avg_glucose_level values have bimodal distribution and bmi distribution is skewed to the right which can affect a perfomance of as selected model. Therefore it is reasonable to transform these features into categories.

# %%
# Create histograms of two continous variables
sns.set(rc = {'figure.figsize':(15,8)})
fig, ax =plt.subplots(1,2)
sns.histplot(data_adult['avg_glucose_level'], ax=ax[0])
sns.histplot(data_adult['bmi'], ax=ax[1])
plt.suptitle('Distribution of "bmi" and "glucose_level" variables')
plt.show()

# %% [markdown]
# ## To transform bmi features, we will use universally accepted bmi ranges as follows:
# * ## below 18.5 – underweight
# * ## between 18.5 and 24.9 – normal weight
# * ## between 25 and 29.9 – overweight
# * ## between 30 and 39.9 – obesity

# %%
# Create a categorical variable 'bmi' in the 'data_adult' dataframe
# The 'pd.cut' method is used to bin the numerical values in the 'bmi' column, dropping any missing values first
data_adult['bmi'] = pd.cut(data_adult['bmi'].dropna(),
                         [0,18.5, 24.9, 29.9,100],labels=["underweight", "normal", "overweight","obese"])

# %% [markdown]
# ## Next we can put all NaN values into 'unknown' category.

# %%
# Use fillna method to replace missing values with 'unknown'
data_adult['bmi'] = data_adult['bmi'].astype('object')
data_adult.bmi = data_adult.bmi.fillna('unknown')

# %%
# Count distinct values in the bmi variable
bmi_counts = pd.DataFrame(data_adult.bmi.value_counts())
sns.barplot(x=bmi_counts.index,y='bmi',data=bmi_counts) 
plt.title('Distribution of categories in the "bmi"  variable')
plt.show()

# %% [markdown]
# ## We will replace glucose values with categories as follows:
# * ## below 140 - normal
# * ## 140-199 - prediabetes
# * ## over 200 - diabetes

# %%
# Create a categorical variable 'avg_glucose_level' in the 'data_adult' dataframe
# The 'pd.cut' method is used to bin the numerical values in the 'avg_glucose_level' column
data_adult['avg_glucose_level'] = pd.cut(data_adult['avg_glucose_level'],
                         [0,139.9, 199.9, 300],labels=["normal", "prediabetes", "diabetes"])

# %%
# Count distinct values in the avg_glucose_level variable
glucose_counts = pd.DataFrame(data_adult.avg_glucose_level.value_counts()).sort_values(by='avg_glucose_level',ascending=False)
sns.barplot(x=glucose_counts.index,y='avg_glucose_level',data=glucose_counts,order=glucose_counts.index) 
plt.title('Distribution of categories in the "avg_glucose_level"  variable')
plt.show()

# %%
# rename column to remove 'avg_' part
data_adult.rename(columns={"avg_glucose_level": "glucose_level"},inplace=True)

# %%
# create a barplot with 'bmi' on the x-axis and 'stroke' on the y-axis, using the specified order of BMI categories
sns.barplot(x='bmi',y='stroke',data=data_adult,order=['unknown','overweight','obese','normal','underweight'])
plt.title('Relationship of BMI categories and stroke',fontsize=15)
plt.xlabel('BMI', fontsize=15)
plt.ylabel('Stroke', fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# ## We will also divide age into several bins.

# %%
# Create a categorical variable 'age' in the 'data_adult' dataframe
# The 'pd.cut' method is used to bin the numerical values in the 'age' column
data_adult['age'] = pd.cut(data_adult['age'],
                         [0, 18, 30, 45, 60, 80, 99])

# %% [markdown]
# ## Split data set

# %%
# Split dataset into y target variable and X predictor variables
y = data_adult[['stroke']]
X = data_adult.drop(['stroke'],axis=1)

# %%
# Split the dataset into training and testing sets using a 70-30 ratio
# Set a random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Next we need to encode categorical variables.
# ## Since all the categorical variables have K mutually exclusive categories, we actually only need K – 1 new dummy variables to encode the same information. Therefore we can use drop_first = True

# %%
# Convert categorical variables to dummy variables for training and testing data
X_train = pd.get_dummies(X_train, drop_first = True)
X_test = pd.get_dummies(X_test, drop_first = True)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((3019, 22), (1294, 22), (3019, 1), (1294, 1))

# %% [markdown]
# ## Next we will save 4 separate dataframes to use in modeling.

# %%
# Save four dataframe to CSV files
X_train.to_csv(r'C:/Users/Julia/Documents/_DATA SCIENCE/_Capstones/Capstone 2/Data/X_train.csv', index=True,header=True)
X_test.to_csv(r'C:/Users/Julia/Documents/_DATA SCIENCE/_Capstones/Capstone 2/Data/X_test.csv', index=True,header=True)
y_train.to_csv(r'C:/Users/Julia/Documents/_DATA SCIENCE/_Capstones/Capstone 2/Data/y_train.csv', index=True,header=True)
y_test.to_csv(r'C:/Users/Julia/Documents/_DATA SCIENCE/_Capstones/Capstone 2/Data/y_test.csv', index=True,header=True)

# %% [markdown]
# ## Next step - Modeling
# ### I will train different models and evaluate the performance to select one optimal model.
